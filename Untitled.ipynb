# %%
# currentWorkingDirectory = "C:\\(...)\\project1"
# #currentWorkingDirectory = "/mount/src/berlingeoheatmap1/"

# # -----------------------------------------------------------------------------
# import os
# os.chdir(currentWorkingDirectory)
# print("Current working directory\n" + os.getcwd())

import pandas                        as pd
from core import methods             as m1
from core import HelperTools         as ht

from config                          import pdict

# -----------------------------------------------------------------------------
# @ht.timer
# def main():
#     """Main: Generation of Streamlit App for visualizing electric charging stations & residents in Berlin"""

#     df_geodat_plz   = pd.read_csv("datasets\geodata_berlin_plz.csv", sep=';')#
    
#     df_lstat        = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx")
#     df_lstat2       = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx")
#     gdf_lstat3      = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister.csv")
    
#     df_residents    = pd.read_csv("datasets\downloaded_datasets\plz_einwohner.csv")
#     # pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx") #I'm not sure
#     gdf_residents2  = pd.read_csv("datasets\geodata_berlin_dis.csv")
    
# # -----------------------------------------------------------------------------------------------------------------------

#     #


# if __name__ == "__main__": 
#     main()

# %%
# First Dataset
df_geodat_plz   = pd.read_csv("datasets\geodata_berlin_plz.csv", sep=';')
df_geodat_plz.head(1)
# Out:
#      PLZ                                           geometry
# 0  10115  POLYGON ((13.372394962330674 52.5382088029012,...

# %%
# Second Dataset
gdf_residents2  = pd.read_csv("datasets\geodata_berlin_dis.csv", sep=';')
gdf_residents2.head(1)
# Out:
#           Bezirk                                           geometry
# 0  Reinickendorf  POLYGON ((13.320744327762688 52.6265990635977,...

# %%
# Third and Fourth Dataset
"""
Focuses on the charging stations
"""
df_lstat = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister.csv", sep=",")
df_lstat.head(1)
# df_lstat2       = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[31], line 5
#       1 # Third and Fourth Dataset
#       2 """
#       3 Focuses on the charging stations
#       4 """
# ----> 5 df_lstat = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister.csv", sep=",")
#       6 df_lstat.head(1)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3 fields in line 5, saw 4

# %%
# # Fifth dataset
# gdf_lstat3      = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister.csv")

# %%
# Last dataset
df_residents    = pd.read_csv("datasets\downloaded_datasets\plz_einwohner.csv")
df_residents.head(1)
# Out:
#     plz           note  einwohner       qkm       lat       lon
# 0  1067  01067 Dresden      11957  6.866839  51.06019  13.71117

# %%
df_lstat = pd.read_excel("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx", header=10)
# df_lstat = df_lstat.iloc[10:]
df_lstat.head(10)
# Out:
#                                   Betreiber    Anzeigename (Karte)  \
# 0                     Albwerk GmbH & Co. KG  Albwerk GmbH & Co. KG
# 1  smopi® - Multi Chargepoint Solution GmbH                  smopi
# 2  smopi® - Multi Chargepoint Solution GmbH                  smopi
# 3  smopi® - Multi Chargepoint Solution GmbH                  smopi
# 4                     Albwerk GmbH & Co. KG  Albwerk GmbH & Co. KG
# 5              EnBW mobility+ AG und Co.KG                     NaN
# 6                          SWU Energie GmbH                    NaN
# 7                    Shell Deutschland GmbH                    NaN
# 8              EnBW mobility+ AG und Co.KG                     NaN
# 9              EnBW mobility+ AG und Co.KG                     NaN
#
#                    Straße Hausnummer Adresszusatz  Postleitzahl  \
# 0          Ennabeurer Weg          0          NaN         72535
# 1               Albstraße         15          NaN         72535
# 2               Albstraße         15          NaN         72535
# 3               Albstraße         15          NaN         72535
# 4  Parkplatz Campingplatz          0          NaN         72589
# 5             Hauptstraße        91c          NaN         73340
# 6              Sterngasse          6          NaN         88481
# 7              Kiesgräble          2          NaN         89129
# 8                Karlstr.         45          NaN         89129
# 9               Flurstück        313          NaN         89129
#
#                     Ort     Kreis/kreisfreie Stadt         Bundesland  \
# 0           Heroldstatt  Landkreis Alb-Donau-Kreis  Baden-Württemberg
# 1           Heroldstatt  Landkreis Alb-Donau-Kreis  Baden-Württemberg
# 2           Heroldstatt  Landkreis Alb-Donau-Kreis  Baden-Württemberg
# 3           Heroldstatt  Landkreis Alb-Donau-Kreis  Baden-Württemberg
# 4            Westerheim  Landkreis Alb-Donau-Kreis  Baden-Württemberg
# 5             Amstetten  Landkreis Alb-Donau-Kreis  Baden-Württemberg
# 6              Balzheim  Landkreis Alb-Donau-Kreis  Baden-Württemberg
# 7              Langenau  Landkreis Alb-Donau-Kreis  Baden-Württemberg
# 8              Langenau  Landkreis Alb-Donau-Kreis  Baden-Württemberg
# 9  Langenau/Seligweiler  Landkreis Alb-Donau-Kreis  Baden-Württemberg
#
#   Breitengrad  ... Public Key3       Steckertypen4  P4 [kW] Public Key4  \
# 0   48,442398  ...         NaN                 NaN      NaN         NaN
# 1   48,449424  ...         NaN  AC Typ 2 Steckdose     22.0         NaN
# 2   48,449424  ...         NaN  AC Typ 2 Steckdose     22.0         NaN
# 3   48,449424  ...         NaN                 NaN      NaN         NaN
# 4     48,5105  ...         NaN                 NaN      NaN         NaN
# 5   48,578534  ...         NaN                 NaN      NaN         NaN
# 6   48,179959  ...         NaN                 NaN      NaN         NaN
# 7    48,49339  ...         NaN                 NaN      NaN         NaN
# 8   48,500374  ...         NaN                 NaN      NaN         NaN
# 9   48,456817  ...         NaN                 NaN      NaN         NaN
#
#    Steckertypen5 P5 [kW]  Public Key5 Steckertypen6 P6 [kW]  Public Key6
# 0            NaN     NaN          NaN           NaN     NaN          NaN
# 1            NaN     NaN          NaN           NaN     NaN          NaN
# 2            NaN     NaN          NaN           NaN     NaN          NaN
# 3            NaN     NaN          NaN           NaN     NaN          NaN
# 4            NaN     NaN          NaN           NaN     NaN          NaN
# 5            NaN     NaN          NaN           NaN     NaN          NaN
# 6            NaN     NaN          NaN           NaN     NaN          NaN
# 7            NaN     NaN          NaN           NaN     NaN          NaN
# 8            NaN     NaN          NaN           NaN     NaN          NaN
# 9            NaN     NaN          NaN           NaN     NaN          NaN
#
# [10 rows x 33 columns]

# %%
df_lstat.columns
# Out:
# Index(['Betreiber', 'Anzeigename (Karte)', 'Straße', 'Hausnummer',
#        'Adresszusatz', 'Postleitzahl', 'Ort', 'Kreis/kreisfreie Stadt',
#        'Bundesland', 'Breitengrad', 'Längengrad', 'Inbetriebnahmedatum',
#        'Nennleistung Ladeeinrichtung [kW]', 'Art der Ladeeinrichung',
#        'Anzahl Ladepunkte', 'Steckertypen1', 'P1 [kW]', 'Public Key1',
#        'Steckertypen2', 'P2 [kW]', 'Public Key2', 'Steckertypen3', 'P3 [kW]',
#        'Public Key3', 'Steckertypen4', 'P4 [kW]', 'Public Key4',
#        'Steckertypen5', 'P5 [kW]', 'Public Key5', 'Steckertypen6', 'P6 [kW]',
#        'Public Key6'],
#       dtype='object')

# %%
 gdf_lstat3      = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gdf_lstat3      = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4, saw 2

# %%
df_lstat2       = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx")
    gdf_lstat3      = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister.csv")
    
    df_residents    = pd.read_csv("datasets\downloaded_datasets\plz_einwohner.csv")
    # pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx") #I'm not sure
    gdf_residents2  = pd.read_csv("datasets\geodata_berlin_dis.csv")

# %%
# currentWorkingDirectory = "C:\\(...)\\project1"
# #currentWorkingDirectory = "/mount/src/berlingeoheatmap1/"

# # -----------------------------------------------------------------------------
# import os
# os.chdir(currentWorkingDirectory)
# print("Current working directory\n" + os.getcwd())

import pandas                        as pd
from core import methods             as m1
from core import HelperTools         as ht

from config                          import pdict

# -----------------------------------------------------------------------------
@ht.timer
def main():
    """Main: Generation of Streamlit App for visualizing electric charging stations & residents in Berlin"""

    df_geodat_plz   = pd.read_csv("datasets\geodata_berlin_dis.csv")#
    
    df_lstat        = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx")
    df_lstat2       = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx")
    gdf_lstat3      = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister.csv")
    
    df_residents    = pd.read_csv("datasets\downloaded_datasets\plz_einwohner.csv")
    # pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx") #I'm not sure
    gdf_residents2  = pd.read_csv("datasets\geodata_berlin_plz.csv")
    
# -----------------------------------------------------------------------------------------------------------------------

    #


if __name__ == "__main__": 
    main()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 36
#      30 # -----------------------------------------------------------------------------------------------------------------------
#      31
#      32     #
#      35 if __name__ == "__main__":
# ---> 36     main()
#
# File ~\Downloads\berlingeoheatmap_project1-main\berlingeoheatmap_project1-main\core\HelperTools.py:18, in timer.<locals>.wrapper_timer(*args, **kwargs)
#      15 @functools.wraps(func)
#      16 def wrapper_timer(*args, **kwargs):
#      17     start_time = time.perf_counter()  # 1
# ---> 18     value = func(*args, **kwargs)
#      19     end_time = time.perf_counter()  # 2
#      20     run_time = end_time - start_time  # 3
#
# Cell In[7], line 20, in main()
#      16 @ht.timer
#      17 def main():
#      18     """Main: Generation of Streamlit App for visualizing electric charging stations & residents in Berlin"""
# ---> 20     df_geodat_plz   = pd.read_csv("datasets\geodata_berlin_dis.csv")#
#      22     df_lstat        = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx")
#      23     df_lstat2       = pd.read_csv("datasets\downloaded_datasets\Ladesaeulenregister_SEP.xlsx")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2436 fields in line 4, saw 3817
